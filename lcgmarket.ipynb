# %%
import requests
import random
import json
import time
import re
requests.packages.urllib3.disable_warnings()

UA="Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Mobile Safari/537.36"
user_cookie={
"mengpanfei":"_s0=eNpFkMtu00AUhhcIVISoyhugqqsqMTO2ZzyTFYnjNo5rW6kNKV5gfBm7Jh478TjNpULiIVjABhaseSyQeAuC0qq7T9%2F5j36dMzoSTIiirsKlYE04YxsdvEpqLkVlsVlWUlrzqKikuhJRyaQVi6XdkNeV5O3XzCqrvx7sw9b8Dsz0cA9OkcyqiLPDe%2B%2FvBGuf3nWa6UHbLJmzSzxmu57yCa%2FjomQfjqBCZUwI1mSIiKopj37%2F%2BvHny%2Be%2FP78%2FEPhGxKnto3ZcKiE8OVnZ%2BCJ3V2RWGuVsw4O2MS0%2B9FMxoetiQD4adkPpNmYt5FlInHn9Jhy4%2Fkq%2F9ge1Y8NgzFiaWXS7flfFDrquhViYgd7gVvPO15dFzmU9VrPzSE8HwdTc8jwdLbC4ugomuWqdTZfZ5mbO3p4CrgPwMiWQajjBSI0SFSoZAVDW1DgBVIlhlpGHM15wVuXzqMpY8Xqx%2BP%2FeZxBBCAABAMHnnuF5puuEtjs0LsD72yLtHSOIMSYa7I4Caox921V9RCZD7PTN6VTpnvXxpeP2ra5PfOocd5K2BxEFSJUhlZGCOlFyLzCmFJAOX%2Ffgru5T8A%2FdyLJB; Path=/; HttpOnly",
}

def get_httpheader(username="mengpanfei",refer='https://mi.aliyun.com/'):
    if username=="random": 
        username=random.choice(list(user_cookie.keys()))
    if username=="UA": username="mengpanfei"
    Cookie=user_cookie.get(username)
    headers={'Cookie':Cookie,'Referer':refer,'User-Agent':UA,'accept':'application/json',
             'Pragma':'no-cache','Cache-Control':'no-cache','content-type':'application/json'}
    return headers




def get_url_data(url,param,headers,MaxTry=2):
    r=None
    while MaxTry>0:
        try:
            r=requests.post(url,data=param,headers=headers,verify=False)
            if r.json()['errorNo'] in ('00',"30001","30008"): #30001狗状态改变不能操作，30008下架太频繁不能操作
                break
        except Exception as ex:
            print(ex)
            pass
        MaxTry-=1
        time.sleep(0.54)
    return r

def get_selling_domain(suffix="com"):
    headers=get_httpheader("mengpanfei")
    token="tdomain-aliyun-com:fsnDNnSvJzVWZ3sfhBVDsPzfJzrYaRp8"

    domains=[]
    suffix="com"
    minPrice=1
    maxPrice=10
    currentPage=1
    totalCount=500
    while True:
        if currentPage * 500 > totalCount: break
        url="https://domainapi.aliyun.com/onsale/search?fetchSearchTotal=true&token={token}&currentPage={currentPage}&pageSize=500&suffix={suffix}&minPrice={minPrice}&maxPrice={maxPrice}&searchIntro=false&keywordAsPrefix=false&keywordAsSuffix=false&exKeywordAsPrefix=false&exKeywordAsSuffix=false&exKeywordAsPrefix2=false&exKeywordAsSuffix2=false&callback=jQuery111106068888000014647_{_}&_={_}"\
            .format(token=token,currentPage=currentPage,suffix=suffix,minPrice=minPrice,maxPrice=maxPrice,_=int(time.time() * 1000)) # _=int(time.time() * 1000)
        r=requests.get(url,headers=headers,verify=False)
#         print(r.text)
        jr=json.loads(re.findall("\((.+)\)",r.text)[0])
        totalCount=jr["data"]["searchTotal"]
        currentPage+=1
        for domain in jr["data"]["pageResult"]["data"]:
            domains.append(domain)
    return domains

# %%
domains=get_selling_domain()

## productType: 13=议价域名, 2=一口价, 4=竞价
for dom in domains:
    if dom["productType"]==13: continue
    if not re.match("[a-z0-9\.]",dom["domainName"]): continue
    price="-"
    if "price" in dom:
        price=dom["price"]
    if int(price)>2: continue #只要1块钱的
    print(dom["deadDate"],dom["productType"],price,dom["domainName"],dom["endTimeRemainingDay"])
# Out:
# jQuery111106068888000014647_1590543363552({"code":"200","data":{"searchTotal":1091,"pageResult":{"currentPageNum":1,"data":[{"bailPrice":"0","constitute":"13\t1303","create_date":"0","deadDate":"2020-05-29","domainName":"2klf.com","endTime":"2020-05-27 10:05:00","endTimeRemaining":1736081,"endTimeRemainingDay":"28\u5206\u949F","idnDomain":false,"introduction":"\u53BB\u5F00\u623F\u4E86","orgPlatForm":"","orgType":0,"price":"10","priceNegotiable":"","productType":2,"publishTime":"2020-05-26 16:34:20","punycode":"2klf.com","recommend":0,"regDate":"2019-05-29","sale_status":0,"store_limit_status":0,"store_status":0,"store_user_limit_status":0,"store_view_count":0,"update_date":"0"},{"bailPrice":"0","constitute":"11","create_date":"0","deadDate":"2020-06-06","domainName":"0553738525.com","endTime":"2020-05-27 11:55:00","endTimeRemaining":8336079,"endTimeRemainingDay":"2\u5C0F\u65F618\u5206\u949F","idnDomain":false,"introduction":"","orgPlatForm":"","orgType":0,"price":"5","priceNegotiable":"","productType":2,"publishTime":"2020-05-26 11:56:51","punycode":"0553738525.com","recommend":0,"regDate":"2019-06-06","sale_status":0,"store_limit_status":0,"store_status":0,"store_user_limit_status":0,"store_view_count":0,"update_date":"0"},{"bailPrice":"0","constitute":"","create_date":"0","deadDate":"2020-06-06","domainName":"g-tphoto.com","endTime":"2020-05-27 11:55:00","endTimeRemaining":8336078,"endTimeRemainingDay":"2\u5C0F\u65F618\u5206\u949F","idnDomain":false,"introduction":"","orgPlatForm":"","orgType":0,"price":"5","priceNegotiable":"","productType":2,"publishTime":"2020-05-26 11:56:27","punycode":"g-tphoto.com","recommend":0,"regDate":"2019-06-06","sale_status":0,"store_limit_status":0,"store_status":0,"store_user_limit_status":0,"store_view_count":0,"update_date":"0"},{"bailPrice":"0","constitute":"","create_date":"0","deadDate":"2020-06-06","domainName":"279-1500.com","endTime":"2020-05-27 11:55:00","endTimeRemaining":8336076,"endTimeRemainingDay":"2\u5C0F\u65F618\u5206\u949F","idnDomain":false,"introduction":"","orgPlatForm":"","orgType":0,"price":"5","priceNegotiable":"","productType":2,"publishTime":"2020-05-26 13:01:36","punycode":"279-1500.com","recommend":0,"regDate":"2019-06-06","sale_status":0,"store_limit_status":0,"store_status":0,"store_user_limit_status":0,"store_view_count":0,"update_date":"0"},{"bailPrice":"0","constitute":"1206\t12","create_date":"0","deadDate":"2020-06-07","domainName":"hunorc.com","endTime":"2020-05-27 11:55:00","endTimeRemaining":8336074,"endTimeRemainingDay":"2\u5C0F\u65F618\u5206\u949F","idnDomain":false,"introduction":"","orgPlatForm":"","orgType":0,"price":"5","priceNegotiable":"","productType":2,"publishTime":"2020-05-26 15:03:56","punycode":"hunorc.com","recommend":0,"regDate":"2019-06-07","sale_status":0,"store_limit_status":0,"store_status":0,"store_user_limit_status":0,"store_view_count":0,"update_date":"0"},{"bailPrice":"0","constitute":"","create_date":"0","deadDate":"2020-06-06","domainName":"al-esgomri.com","endTime":"2020-05-27 11:55:00","endTimeRemaining":8336073,"endTimeRemainingDay":"2\u5C0F\u65F618\u5206\u949F","idnDomain":false,"introduction":"","orgPlatForm":"","orgType":0,"price":"5","priceNegotiable":"","productType":2,"publishTime":"2020-05-26 11:56:51","punycode":"al-esgomri.com","recommend":0,"regDate":"2019-06-06","sale_status":0,"store_limit_status":0,"store_status":0,"store_user_limit_status":0,"store_view_count":0,"update_date":"0"},{"bailPrice":"0","constitute":"12","create_date":"0","deadDate":"2020-06-06","domainName":"tiklayaa.com","endTime":"2020-05-27 11:55:00","endTimeRemaining":8336071,"endTimeRemainingDay":"2\u5C0F\u65F618\u5206\u949F","idnDomain":false,"introduction":"","orgPlatForm":"","orgType":0,"price":"5","priceNegotiable":"","productType":2,"publishTime":"2020-05-26 15:03:56","punycode":"tiklayaa.com","recommend":0,"regDate":"2019-06-06","sale_status":0,"store_limit_status":0,"store_status":0,"store_user_limit_status":0,"store_view_count":0,"update_da ...
# jQuery111106068888000014647_1590543364881({"code":"200","data":{"searchTotal":1091,"pageResult":{"currentPageNum":2,"data":[{"bailPrice":"0","constitute":"1206\t12\t1207003\t1207","create_date":"0","deadDate":"2020-06-29","domainName":"anfuxi.com","endTime":"\u957F\u671F","endTimeRemainingDay":"\u957F\u671F","idnDomain":false,"introduction":"\u57DF\u540D\u76F8\u5F53\u4E8E\u95E8\u724C\u53F7\u3001\u7F51\u7EDC\u5730\u76AE\u3001\u5B9E\u4F53\u5E97\u5730\u5740\u3001\u53EF\u6CE8\u518C\u4E3A\u7ECF\u8425\u573A\u6240\uFF01\u4EF7\u683C\u53EF\u534F\u5546\uFF0C\u624B\u673A15858115812","orgPlatForm":"","orgType":0,"priceNegotiable":"","productType":13,"publishTime":"2020-05-14 00:25:19","punycode":"anfuxi.com","recommend":0,"regDate":"2019-06-29","sale_status":0,"store_limit_status":0,"store_status":0,"store_user_limit_status":0,"store_view_count":0,"update_date":"0"},{"bailPrice":"0","constitute":"12\t1207003\t1207","create_date":"0","deadDate":"2020-06-30","domainName":"fumaiyi.com","endTime":"\u957F\u671F","endTimeRemainingDay":"\u957F\u671F","idnDomain":false,"introduction":"\u57DF\u540D\u76F8\u5F53\u4E8E\u95E8\u724C\u53F7\u3001\u7F51\u7EDC\u5730\u76AE\u3001\u5B9E\u4F53\u5E97\u5730\u5740\u3001\u53EF\u6CE8\u518C\u4E3A\u7ECF\u8425\u573A\u6240\uFF01\u4EF7\u683C\u53EF\u534F\u5546\uFF0C\u624B\u673A15858115812","orgPlatForm":"","orgType":0,"priceNegotiable":"","productType":13,"publishTime":"2020-05-14 00:25:19","punycode":"fumaiyi.com","recommend":0,"regDate":"2019-06-30","sale_status":0,"store_limit_status":0,"store_status":0,"store_user_limit_status":0,"store_view_count":0,"update_date":"0"},{"bailPrice":"0","constitute":"12\t1207003\t1207004\t1207","create_date":"0","deadDate":"2020-12-26","domainName":"xiezhuni.com","endTime":"\u957F\u671F","endTimeRemainingDay":"\u957F\u671F","idnDomain":false,"introduction":"\u90D1\u91CD\u63D0\u9192\uFF0C\u6536\u8D2D\u672C\u57DF\u540D\u514D\u8D39\u5E2E\u5EFA\u7F51\u7AD9\u5C0F\u7A0B\u5E8F\u516C\u4F17\u53F7\uFF0C\u8BE6\u7EC6\u54A8\u8BE2\u624B\u673A\u5FAE\u4FE1\u540C\u53F715858115812\u5180\u5E08\u5085","orgPlatForm":"","orgType":0,"priceNegotiable":"","productType":13,"publishTime":"2020-05-14 00:25:19","punycode":"xiezhuni.com","recommend":0,"regDate":"2018-12-26","sale_status":0,"store_limit_status":0,"store_status":0,"store_user_limit_status":0,"store_view_count":0,"update_date":"0"},{"bailPrice":"0","constitute":"1206\t12\t1207003\t1207","create_date":"0","deadDate":"2020-06-05","domainName":"biyihe.com","endTime":"\u957F\u671F","endTimeRemainingDay":"\u957F\u671F","idnDomain":false,"introduction":"\u8D85N\u5E74\u8001\u57DF\u540D\uFF0C\u90D1\u91CD\u63D0\u9192\uFF0C\u6536\u8D2D\u672C\u57DF\u540D\u514D\u8D39\u5E2E\u5EFA\u7F51\u7AD9\u5C0F\u7A0B\u5E8F\u516C\u4F17\u53F7\uFF0C\u8BE6\u7EC6\u54A8\u8BE2\u624B\u673A\u5FAE\u4FE1\u540C\u53F715858115812\u5180\u5148\u751F","orgPlatForm":"","orgType":0,"priceNegotiable":"","productType":13,"publishTime":"2020-05-14 00:23:02","punycode":"biyihe.com","recommend":0,"regDate":"2019-06-05","sale_status":0,"store_limit_status":0,"store_status":0,"store_user_limit_status":0,"store_view_count":0,"update_date":"0"},{"bailPrice":"0","constitute":"12\t1207003\t1207","create_date":"0","deadDate":"2020-08-26","domainName":"yunqidi.com","endTime":"\u957F\u671F","endTimeRemainingDay":"\u957F\u671F","idnDomain":false,"introduction":"\u8D85N\u5E74\u8001\u57DF\u540D\uFF0C\u90D1\u91CD\u63D0\u9192\uFF0C\u6536\u8D2D\u672C\u57DF\u540D\u514D\u8D39\u5E2E\u5EFA\u7F51\u7AD9\u5C0F\u7A0B\u5E8F\u516C\u4F17\u53F7\uFF0C\u8BE6\u7EC6\u54A8\u8BE2\u624B\u673A\u5FAE\u4FE1\u540C\u53F715858115812\u5180\u5148\u751F","orgPlatForm":"","orgType":0,"priceNegotiable":"","productType":13,"publishTime":"2020-05-14 00:28:11","punycode":"yunqidi.com","recommend":0,"regDate":"2015-08-26","sale_status":0,"store_limit_status":0,"store_status":0,"store_user_limit_status":0,"store_view_count":0,"update_date":"0"},{"bailPrice":"0","constitute":"1206\t12\t1207003\t1207","create_date":"0","deadDate":"2020-08-16","domainN ...
# 2021-01-07 4 1 hiaichain.com 12小时23分钟
# 2021-04-13 4 1 huibaigou.com 12小时23分钟
# 2021-03-11 4 1 xwicloud.com 12小时23分钟
# 2020-08-03 4 1 chaodaka.com 12小时23分钟
# 2021-01-07 4 1 aichainapp.com 12小时23分钟
# 2020-12-23 4 1 dilushenshi.com 12小时23分钟
# 2020-07-01 4 1 bangdisi.com 12小时23分钟
# 2020-06-09 4 1 jdququgou.com 12小时29分钟
# 2020-06-16 4 2 miaomanfen.com 12小时29分钟
# 2021-01-23 4 1 tiantanglei.com 1天6小时9分钟
# 2023-04-10 4 1 vqsz.com 1天8小时46分钟
# 2023-11-29 4 1 vwwl.com 1天8小时46分钟
# 2021-01-08 4 1 eqgy.com 1天8小时46分钟
# 2021-06-04 4 1 pgua.com 1天8小时46分钟
# 2022-01-07 4 1 illz.com 1天8小时46分钟
# 2020-08-20 4 1 fuhuahe.com 2天11小时51分钟
# 2020-07-05 4 1 heichezi.com 3天39分钟
# 2020-07-05 4 1 huangchezi.com 3天1小时43分钟
# 2020-07-31 4 1 iosshouzhuan.com 3天14小时22分钟
# 2020-07-03 4 1 bjjzx.com 4天8小时3分钟
# 2021-03-31 4 1 gtsts.com 4天8小时3分钟
# 2020-11-12 2 1 5elicai.com 长期
# 2020-11-16 2 1 100jiyi.com 长期
# 2020-11-14 2 1 chjfu.com 长期
# 2020-11-28 2 1 gdylink.com 长期
# 2020-11-16 2 1 6faka.com 长期
# 2020-05-27 2 2 hongmengex.com 长期
